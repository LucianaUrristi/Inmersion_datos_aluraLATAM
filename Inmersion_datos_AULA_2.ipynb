# %% [markdown]
# <a href="https://colab.research.google.com/github/LucianaUrristi/Inmersion_datos_aluraLATAM/blob/main/Inmersion_datos_AULA_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **AULA 2**

# %%
import os

aula1 = "/content/drive/MyDrive/Inmersion_datos_aluraLATAM/Inmersion_datos_AULA_1.ipynb" #importa la ruta de acceso
if os.path.isfile(aula1):
    # Abre el notebook
    # %run "$aula1"
else:
    print("El archivo no existe en la ubicación especificada.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB
# Primeras 10 areas:
# 0     70
# 1    170
# 2    144
# 3    154
# 4    128
# 5     62
# 6     62
# 7    212
# 8    159
# 9     80
# Name: Area, dtype: int64
# Promedio de estas 10 primeras áreas:  124.1
# Menor cantidad de inmuebles dentro de un barrio:  332
# ...

# %%
inmuebles.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 595.1+ KB

# %%
inmuebles.Valor[0]
# Out:
# 360000000.0

# %%
inmuebles.Valor[0].split() #me separa la cadena de texto en funcion de algun parametro que le pase.
#si no se especifica, por default me toma el espacio y el $. Sigue siendo panda series

# %%
inmuebles.Valor.str.split() #sigue siendo un panda series pero cada elemento me lo devuelve una columna de tipo series
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-c67eaf84a999> in <cell line: 1>()
# ----> 1 inmuebles.Valor.str.split() #sigue siendo un panda series pero cada elemento me lo devuelve una columna de tipo series
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
# ...

# %%
valor = inmuebles.Valor.str.split(expand=True) #me devuelve un data frame unicamente con la info de valor, en un formato de 2 columnas. De esta manera puede generar nuevas columnas
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]

inmuebles.sample(3)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 687   Apartamento   Apartamento en venta en Santa Barbara             3
# 2487  Apartamento  Apartamento en venta en Barrios Unidos             3
# 7386  Apartamento         Apartamento en venta en Usaquén             2
#
#       Baños  Área          Barrio                                    UPZ  \
# 687       3    89   Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 2487      2    92  Barrios Unidos                              Los Andes
# 7386      1    45         Usaquén                                Usaquén
#
#               Valor Moneda       Precio
# 687   $ 500.000.000      $  500.000.000
# 2487  $ 278.000.000      $  278.000.000
# 7386  $ 185.869.000      $  185.869.000

# %%
inmuebles.info() #para verificar el tipo de dato que queda en mi data frame
#moneda y precio siguen siendo objetos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 595.1+ KB

# %%
inmuebles['Precio'].sum() #como siguen siendo str, concatena todos los precios
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Precio'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.', '', regex = True) #para sustituir el punto
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Precio'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
inmuebles[['Precio', 'Barrio']] #formato de lista y un dataframe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-ada1f96fe903> in <cell line: 1>()
# ----> 1 inmuebles[['Precio', 'Barrio']] #formato de lista y un dataframe
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# ...

# %%
inmuebles.info() #aun sigue siendo objeto, por lo que hay que pasarlo a numero
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 595.1+ KB

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
inmuebles.info() #ahora si cambio el tipo de dato
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-7cf462ca5a1a> in <cell line: 1>()
# ----> 1 inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
#       2 inmuebles.info() #ahora si cambio el tipo de dato
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Precio'

# %%
inmuebles.describe() #devuelve el conteo de filas, la mediana, el promedio, el desvio estandar, el valor minimo, el valor max
# Out:
#        Habitaciones        Baños           Área  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x:'%.2f' % x) #para que solo muestre 2 decimales
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area          Valor
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66   602062353.53
# std            2.05    1.26   1731.38   704602061.61
# min            1.00    0.00      2.00    60000000.00
# 25%            2.00    2.00     57.00   250000000.00
# 50%            3.00    2.00     80.00   409182500.00
# 75%            3.00    3.00    135.00   680000000.00
# max          110.00    9.00 166243.00 16000000000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Baños  Área    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
#histograma: como se comportan la cantidad de repeticiones de una variable

inmuebles['Precio_Millon'].plot.hist(bins = 100) #en x el precio de los inmuebles en millones
#mientras mas bins mas detallado el grafico
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (10, 6)) #creamos lienzo plt. establecemos parametros (size) en tamaño 10 (ancho) x 6 (alto) del lienzo
grafica = sns.histplot(data = inmuebles, x = 'Precio_Millon', kde = True, hue = 'Tipo') #grafico del histograma // (kde = True) comportamiento a traves de una curva de densidad
# (hue = 'Tipo') especifica el tipo de inmueble, si son casas, edificios, bodegas
grafica.set_title('Distribucion de Valores de los inmuebles en Bogotá') #se le puede agragar un titulo a la grafica
plt.xlim(50, 1000) #establece los limites para el eje X el grafico
#plt.ylim (0, 20)  #establece los limites para el eje Y el grafico
plt.savefig('/content/drive/MyDrive/Inmersion en datos aluraLATAM/valor_inmuebles.png', format = 'png') #para guardar el grafico como una imagen, se le pasa el destino y el formato
plt.show() #lo muestra

# %% [markdown]
# **Desafios**
#
# 1. Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles
# (Refinar el gráfico: Títulos, aumentar el tamaño de labels, colores, conclusion de la informacion)
#
# 2. Precio de m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.
